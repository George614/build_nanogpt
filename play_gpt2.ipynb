# %%
from transformers import GPT2LMHeadModel

# %%
model_hf = GPT2LMHeadModel.from_pretrained("gpt2")
sd_hf = model_hf.state_dict()

for k, v in sd_hf.items():
    print(f"key {k} has shape {v.shape}")
# Out:
# key transformer.wte.weight has shape torch.Size([50257, 768])
# key transformer.wpe.weight has shape torch.Size([1024, 768])
# key transformer.h.0.ln_1.weight has shape torch.Size([768])
# key transformer.h.0.ln_1.bias has shape torch.Size([768])
# key transformer.h.0.attn.c_attn.weight has shape torch.Size([768, 2304])
# key transformer.h.0.attn.c_attn.bias has shape torch.Size([2304])
# key transformer.h.0.attn.c_proj.weight has shape torch.Size([768, 768])
# key transformer.h.0.attn.c_proj.bias has shape torch.Size([768])
# key transformer.h.0.ln_2.weight has shape torch.Size([768])
# key transformer.h.0.ln_2.bias has shape torch.Size([768])
# key transformer.h.0.mlp.c_fc.weight has shape torch.Size([768, 3072])
# key transformer.h.0.mlp.c_fc.bias has shape torch.Size([3072])
# key transformer.h.0.mlp.c_proj.weight has shape torch.Size([3072, 768])
# key transformer.h.0.mlp.c_proj.bias has shape torch.Size([768])
# key transformer.h.1.ln_1.weight has shape torch.Size([768])
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.imshow(sd_hf['transformer.wpe.weight'], cmap='gray')

# %%
plt.plot(sd_hf['transformer.wpe.weight'][:, 150])
plt.plot(sd_hf['transformer.wpe.weight'][:, 250])
plt.plot(sd_hf['transformer.wpe.weight'][:, 350])
plt.plot(sd_hf['transformer.wpe.weight'][:, 450])

# %%
plt.imshow(sd_hf["transformer.h.1.attn.c_attn.weight"][:400, :400], cmap="gray")

# %%
from transformers import pipeline, set_seed
generator = pipeline('text-generation', model='gpt2')
set_seed(42)
generator("Hello, I'm a lanugage mdoel,", max_length=30, num_return_sequences=5)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "Hello, I'm a lanugage mdoel, but what I do in that role is different than everything else. I'm a professional l"},
#  {'generated_text': "Hello, I'm a lanugage mdoel, this is my first public challenge. I need to get my clan mates to invite me and"},
#  {'generated_text': "Hello, I'm a lanugage mdoel, and you'll hear me playing.\n\nHey, how am I supposed to call you"},
#  {'generated_text': "Hello, I'm a lanugage mdoel, you know my name, nie… well my face is purple… I was wondering if"},
# ...
